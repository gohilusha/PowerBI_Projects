# %% [markdown]
# ### HR Analytics

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Import HR Analytics Data File

# %%
pf=pd.read_csv("C:\\Users\\this pc\\Desktop\\MeriSkill Projects\\HR Analytics\\HR Employee Attrition.csv")

# %%
pwd
# Out:
# 'C:\\Users\\this pc'

# %%
pf.head()
# Out:
#    Age Attrition    Business Travel  Daily Rate              Department  \
# 0   41       Yes      Travel_Rarely        1102                   Sales
# 1   49        No  Travel_Frequently         279  Research & Development
# 2   37       Yes      Travel_Rarely        1373  Research & Development
# 3   33        No  Travel_Frequently        1392  Research & Development
# 4   27        No      Travel_Rarely         591  Research & Development
#
#    Distance From Home Education Level  Gender  JobInvolvement  Job Level  ...  \
# 0                   1   Life Sciences  Female               3          2  ...
# 1                   8   Life Sciences    Male               2          2  ...
# 2                   2           Other    Male               2          1  ...
# 3                   3   Life Sciences  Female               3          1  ...
# 4                   2         Medical    Male               3          1  ...
#
# ...

# %%
pf.shape
# Out:
# (1470, 26)

# %%
pf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 26 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         1470 non-null   int64
#  1   Attrition                   1470 non-null   object
#  2   Business Travel             1470 non-null   object
#  3   Daily Rate                  1470 non-null   int64
#  4   Department                  1470 non-null   object
#  5   Distance From Home          1470 non-null   int64
#  6   Education Level             1470 non-null   object
#  7   Gender                      1470 non-null   object
#  8   JobInvolvement              1470 non-null   int64
#  9   Job Level                   1470 non-null   int64
#  10  Job Role                    1470 non-null   object
#  11  Marital Status              1470 non-null   object
#  12  Monthly Income              1470 non-null   int64
# ...

# %% [markdown]
# ### Check and Remove null values

# %%
pf.isnull().sum()
# Out:
# Age                           0
# Attrition                     0
# Business Travel               0
# Daily Rate                    0
# Department                    0
# Distance From Home            0
# Education Level               0
# Gender                        0
# JobInvolvement                0
# Job Level                     0
# Job Role                      0
# Marital Status                0
# Monthly Income                0
# Monthly Rate                  0
# Number Of Companies Worked    0
# Over Time                     0
# PercentSalaryHike             0
# PerformanceRating             0
# RelationshipSatisfaction      0
# Total Working Years           0
# TrainingTimesLastYear         0
# WorkLifeBalance               0
# YearsAtCompany                0
# YearsInCurrentRole            0
# YearsSinceLastPromotion       0
# YearsWithCurrManager          0
# dtype: int64

# %%
pf.isnull().mean()*100
# Out:
# Age                           0.0
# Attrition                     0.0
# Business Travel               0.0
# Daily Rate                    0.0
# Department                    0.0
# Distance From Home            0.0
# Education Level               0.0
# Gender                        0.0
# JobInvolvement                0.0
# Job Level                     0.0
# Job Role                      0.0
# Marital Status                0.0
# Monthly Income                0.0
# Monthly Rate                  0.0
# Number Of Companies Worked    0.0
# Over Time                     0.0
# PercentSalaryHike             0.0
# PerformanceRating             0.0
# RelationshipSatisfaction      0.0
# Total Working Years           0.0
# TrainingTimesLastYear         0.0
# WorkLifeBalance               0.0
# YearsAtCompany                0.0
# YearsInCurrentRole            0.0
# YearsSinceLastPromotion       0.0
# YearsWithCurrManager          0.0
# dtype: float64

# %%
pf.describe()
# Out:
#                Age   Daily Rate  Distance From Home  JobInvolvement  \
# count  1470.000000  1470.000000         1470.000000     1470.000000
# mean     36.923810   802.485714            9.192517        2.729932
# std       9.135373   403.509100            8.106864        0.711561
# min      18.000000   102.000000            1.000000        1.000000
# 25%      30.000000   465.000000            2.000000        2.000000
# 50%      36.000000   802.000000            7.000000        3.000000
# 75%      43.000000  1157.000000           14.000000        3.000000
# max      60.000000  1499.000000           29.000000        4.000000
#
#          Job Level  Monthly Income  Monthly Rate  Number Of Companies Worked  \
# count  1470.000000     1470.000000   1470.000000                 1470.000000
# mean      2.063946     6502.931293  14313.103401                    2.693197
# std       1.106940     4707.956783   7117.786044                    2.498009
# ...

# %% [markdown]
# ### Rename columns name

# %%
pf.columns=['Age', 'Attrition', 'Business Travel', 'Daily Rate', 'Department',
       'Distance From Home', 'Education Level', 'Gender', 'Job Involvement',
       'Job Level', 'Job Role', 'Marital Status', 'Monthly Income',
       'Monthly Rate', 'Number Of Companies Worked', 'Over Time',
       'Percent Salary Hike', 'Performance Rating', 'Relationship Satisfaction',
       'Total Working Years', 'Training Times Last Year', 'Work Life Balance',
       'Years At Company', 'Years In Current Role', 'Years Since Last Promotion',
       'Years With Curr Manager']

# %%
pf.columns
# Out:
# Index(['Age', 'Attrition', 'Business Travel', 'Daily Rate', 'Department',
#        'Distance From Home', 'Education Level', 'Gender', 'Job Involvement',
#        'Job Level', 'Job Role', 'Marital Status', 'Monthly Income',
#        'Monthly Rate', 'Number Of Companies Worked', 'Over Time',
#        'Percent Salary Hike', 'Performance Rating',
#        'Relationship Satisfaction', 'Total Working Years',
#        'Training Times Last Year', 'Work Life Balance', 'Years At Company',
#        'Years In Current Role', 'Years Since Last Promotion',
#        'Years With Curr Manager'],
#       dtype='object')

# %%
pf.head()

# %% [markdown]
# ### Using Replace function for converting str into numbers
# Column name Attrition(Yes, No) is in string convert into numbers

# %%
pf.head()
# Out:
#    Age Attrition    Business Travel  Daily Rate              Department  \
# 0   41       Yes      Travel_Rarely        1102                   Sales
# 1   49        No  Travel_Frequently         279  Research & Development
# 2   37       Yes      Travel_Rarely        1373  Research & Development
# 3   33        No  Travel_Frequently        1392  Research & Development
# 4   27        No      Travel_Rarely         591  Research & Development
#
#    Distance From Home Education Level  Gender  Job Involvement  Job Level  \
# 0                   1   Life Sciences  Female                3          2
# 1                   8   Life Sciences    Male                2          2
# 2                   2           Other    Male                2          1
# 3                   3   Life Sciences  Female                3          1
# 4                   2         Medical    Male                3          1
#
#    ... Percent Salary Hike Performance Rating  Relationship Satisfaction  \
# ...

# %%
pf["Attrition"]
# Out:
# 0       Yes
# 1        No
# 2       Yes
# 3        No
# 4        No
#        ...
# 1465     No
# 1466     No
# 1467     No
# 1468     No
# 1469     No
# Name: Attrition, Length: 1470, dtype: object

# %%
pf.replace("Yes",1, inplace=True)

# %%
pf.head()
# Out:
#    Age Attrition    Business Travel  Daily Rate              Department  \
# 0   41         1      Travel_Rarely        1102                   Sales
# 1   49        No  Travel_Frequently         279  Research & Development
# 2   37         1      Travel_Rarely        1373  Research & Development
# 3   33        No  Travel_Frequently        1392  Research & Development
# 4   27        No      Travel_Rarely         591  Research & Development
#
#    Distance From Home Education Level  Gender  Job Involvement  Job Level  \
# 0                   1   Life Sciences  Female                3          2
# 1                   8   Life Sciences    Male                2          2
# 2                   2           Other    Male                2          1
# 3                   3   Life Sciences  Female                3          1
# 4                   2         Medical    Male                3          1
#
#    ... Percent Salary Hike Performance Rating  Relationship Satisfaction  \
# ...

# %%
pf.replace("No",0,inplace=True)

# %%
pf.head()
# Out:
#    Age  Attrition    Business Travel  Daily Rate              Department  \
# 0   41          1      Travel_Rarely        1102                   Sales
# 1   49          0  Travel_Frequently         279  Research & Development
# 2   37          1      Travel_Rarely        1373  Research & Development
# 3   33          0  Travel_Frequently        1392  Research & Development
# 4   27          0      Travel_Rarely         591  Research & Development
#
#    Distance From Home Education Level  Gender  Job Involvement  Job Level  \
# 0                   1   Life Sciences  Female                3          2
# 1                   8   Life Sciences    Male                2          2
# 2                   2           Other    Male                2          1
# 3                   3   Life Sciences  Female                3          1
# 4                   2         Medical    Male                3          1
#
#    ... Percent Salary Hike Performance Rating  Relationship Satisfaction  \
# ...

# %%
pf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 26 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         1470 non-null   int64
#  1   Attrition                   1470 non-null   int64
#  2   Business Travel             1470 non-null   object
#  3   Daily Rate                  1470 non-null   int64
#  4   Department                  1470 non-null   object
#  5   Distance From Home          1470 non-null   int64
#  6   Education Level             1470 non-null   object
#  7   Gender                      1470 non-null   object
#  8   Job Involvement             1470 non-null   int64
#  9   Job Level                   1470 non-null   int64
#  10  Job Role                    1470 non-null   object
#  11  Marital Status              1470 non-null   object
#  12  Monthly Income              1470 non-null   int64
# ...

# %% [markdown]
# ### Delete redundant columns in table :
#     Percent Salary Hike, Relationship Satisfaction,
#     Training Times Last Year, WorkLife Balance, Years In Current Role,Years Since Last Promotion,
#     Years With Curr Manager

# %%
pf.shape
# Out:
# (1470, 26)

# %%
pf.drop(['Percent Salary Hike','Relationship Satisfaction','Training Times Last Year','Work Life Balance','Years In Current Role','Years Since Last Promotion','Years With Curr Manager'], axis=1, inplace=True)

# %%
pf.shape
# Out:
# (1470, 19)

# %% [markdown]
# ### Save File

# %%
pf.to_csv("HR Data.csv",index=False)

# %%
pwd
# Out:
# 'C:\\Users\\this pc'
